# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import os
import json
import datetime

# %%
## source: https://github.com/ryendu/sound2ahap/blob/main/utils.py

class AHAP:
    def __init__(self):
        self.data = {
            "Version": 1.0,
            "Metadata": {
                "Project": "Basis",
                "Created": str(datetime.datetime.now()),
                "Description": "AHAP file generated based on a audio file by Basis app.",
                "Created By": "Isabella Gomez"
            },
            "Pattern": []
        }

    def add_event(self, etype, time, parameters, event_duration=None, event_waveform_path=None):
        """
        Adds an event to the pattern
        etype: type of event
            - possible values: AudioContinuous, AudioCustom, HapticTransient, and HapticContinuous
        time: time of event
            - in seconds
        parameters: event parameters
            - as a list of dictionaries
        """
        pattern = {
            "Event": {
                "Time": time,
                "EventType": etype,
                "EventParameters": parameters
            }
        }
        if event_duration != None:
            pattern["Event"]["EventDuration"] = event_duration
        if event_waveform_path != None:
            pattern["Event"]["EventWaveformPath"] = event_waveform_path
        self.data["Pattern"].append(pattern)

    def add_haptic_transient_event(self, time, haptic_intensity, haptic_sharpness):
        """
        Adds a haptic transient event to the pattern
        time: time of event - in seconds
        haptic_intensity: intensity of haptic
        haptic_sharpness: sharpness of haptic
        """
        parameters = [
            {
                "ParameterID": "HapticIntensity",
                "ParameterValue": haptic_intensity,
            },
            {
                "ParameterID": "HapticSharpness",
                "ParameterValue": haptic_sharpness,
            }
        ]

        self.add_event(etype="HapticTransient",
                       time=time, parameters=parameters)

    def add_haptic_continuous_event(self, time, haptic_intensity, haptic_sharpness, event_duration):
        """
        Adds a haptic continuous event to the pattern
        time: time of event - in seconds
        haptic_intensity: intensity of haptic
        haptic_sharpness: sharpness of haptic
        """
        parameters = [
            {
                "ParameterID": "HapticIntensity",
                "ParameterValue": haptic_intensity,
            },
            {
                "ParameterID": "HapticSharpness",
                "ParameterValue": haptic_sharpness,
            }
        ]

        self.add_event(etype="HapticContinuous", time=time,
                       parameters=parameters, event_duration=event_duration)

    def add_audio_custom_event(self, time, wav_filepath, volume=0.75):
        """
        Adds an audio custom event to the pattern
        time: time of event
            - in seconds
        wav_filepath: path to the wav file containing the sound
        volume: volume from 0 to 1
        """
        parameters = [
            {
                "ParameterID": "AudioVolume",
                "ParameterValue": volume,
            }
        ]
        self.add_event(etype="AudioCustom", time=time,
                       parameters=parameters, event_waveform_path=wav_filepath)

    def add_parameter_curve(self, parameter_id, start_time, control_points):
        """
        Adds a parameter curve to the pattern
        parameter_id: the parameter to dynamically change
            - possible values: HapticIntensityControl, HapticSharpnessControl, HapticAttackTimeControl, HapticDecayTimeControl, HapticReleaseTimeControl, AudioBrightnessControl, AudioPanControl, AudioPitchControl, AudioVolumeControl, AudioAttackTimeControl, AudioDecayTimeControl, AudioReleaseTimeControl
        start_time: time of the start of the curve
            - in seconds
        control_points: list of control points
            - as a list of dictionaries in the format: [{"Time":time,"ParameterValue":value}]
        """
        pattern = {
            "ParameterCurve": {
                "ParameterID": parameter_id,
                "Time": start_time,
                "ParameterCurveControlPoints": control_points
            }
        }

        self.data["Pattern"].append(pattern)

    def print_data(self):
        print(self.data)

    def export(self, filename, path):
        with open(os.path.join(path, filename), 'w') as f:
            f.write(json.dumps(self.data))

# %%
## open data
data_left = pd.read_csv('song1/choreo2_lleg.csv', names=['time', 'event'])

data_left.head()
# Out:
#      time  event
# 0  12.411      1
# 1  13.101      1
# 2  17.531      1
# 3  18.321      1
# 4  19.951      1

# %%
data_right = pd.read_csv('song1/choreo2_rleg.csv', names=['time', 'event'])

data_right.head()
# Out:
#      time  event
# 0  15.521      1
# 1  17.241      1
# 2  20.091      1
# 3  23.932      1
# 4  24.582      1

# %%
data = pd.concat([data_left, data_right], ignore_index=True)
data = data.sort_values('time', ignore_index=True)
data['time'] = data['time']-data['time'].iloc[0]+3

data.head()
# Out:
#    time  event
# 0  3.00      1
# 1  3.69      1
# 2  6.11      1
# 3  7.83      1
# 4  8.12      1

# %%
## write ahap

# heel = 0, stamp = 1, toe = 2, toe rev = 3, spin = 4
ahap = AHAP()

## add pulses at the start
ahap.add_haptic_transient_event(0, 0.99, 0.99)
ahap.add_haptic_transient_event(1, 0.99, 0.99)
ahap.add_haptic_transient_event(2, 0.99, 0.99)

funcs = [ahap.add_haptic_transient_event, ahap.add_haptic_continuous_event]
heel = {'event':0, 'sharp':0.05, 'int':0.85}
stamp = {'event':0, 'sharp':0.95, 'int':0.6}
toe = {'event':0, 'sharp':0.1, 'int':0.6}
toe_rev = {'event':0, 'sharp':0.8, 'int':0.5}
spin = {'event':1, 'sharp':0.15, 'int':0.55}

events = [heel, stamp, toe, toe_rev, spin]


for idx, event in data.iterrows():
    time = event['time']
    ev_type = event['event'].astype('int')
    fun = funcs[events[ev_type]['event']]
    sharp = events[ev_type]['sharp']
    int = events[ev_type]['int']

    fun(time, int, sharp)

# %%
## test

# funcs = [ahap.add_haptic_transient_event, ahap.add_haptic_continuous_event]
# heel = {'event':0, 'sharp':0.05, 'int':0.85}
# stamp = {'event':0, 'sharp':0.95, 'int':0.6}
# toe = {'event':0, 'sharp':0.1, 'int':0.6}
# toe_rev = {'event':0, 'sharp':0.8, 'int':0.5}
# spin = {'event':1, 'sharp':0.15, 'int':0.55}

# events = [heel, stamp, toe, toe_rev, spin]

# for idx, event in data.iterrows():
#     time = event['time']
#     print(time)
#     ev_type = event['event'].astype('int')
#     print(ev_type)
#     fun = funcs[events[ev_type]['event']]
#     print(fun)
#     sharp = events[ev_type]['sharp']
#     print(sharp)
#     int = events[ev_type]['int']
#     print(int)
# Out:
# 8.671
# 0
# <bound method AHAP.add_haptic_transient_event of <__main__.AHAP object at 0x1590b2dd0>>
# 0.05
# 0.85
# 10.541
# 0
# <bound method AHAP.add_haptic_transient_event of <__main__.AHAP object at 0x1590b2dd0>>
# 0.05
# 0.85
# 11.151
# 1
# <bound method AHAP.add_haptic_transient_event of <__main__.AHAP object at 0x1590b2dd0>>
# 0.95
# 0.6
# 12.441
# 0
# <bound method AHAP.add_haptic_transient_event of <__main__.AHAP object at 0x1590b2dd0>>
# 0.05
# 0.85
# 12.521
# 1
# <bound method AHAP.add_haptic_transient_event of <__main__.AHAP object at 0x1590b2dd0>>
# 0.95
# 0.6
# 13.651
# 1
# <bound method AHAP.add_haptic_transient_event of <__main__.AHAP object at 0x1590b2dd0>>
# 0.95
# 0.6
# 14.361
# 1
# <bound method AHAP.add_haptic_transient_event of <__main__.AHAP object at 0x1590b2dd0>>
# 0.95
# 0.6
# 14.761
# 1
# <bound method AHAP.add_haptic_transient_event of <__main__.AHAP object at 0x1590b2dd0>>
# 0.95
# 0.6
# 14.801
# 0
# <bound method AHAP.add_haptic_transient_event of <__main__.AHAP object at 0x1590b2dd0>>
# 0.05
# 0.85
# 15.261
# 0
# <bound method AHAP.add_haptic_transient_event of <__main__.AHAP object at 0x1590b2dd0>>
# 0.05
# 0.85
# 16.711
# 0
# <bound method AHAP.add_haptic_transient_event of <__main__.AHAP object at 0x1590b2dd0>>
# 0.05
# 0.85
# 17.101
# 1
# <bound method AHAP.add_haptic_transient_event of <__main__.AHAP object at 0x1590b2dd0>>
# 0.95
# 0.6
# 18.181
# 1
# <bound method AHAP.add_haptic_transient_event of <__main__.AHAP object at 0x1590b2dd0>>
# 0.95
# 0.6
# 18.641
# 0
# <bound method AHAP.add_haptic_transient_event of <__main__.AHAP object at 0x1590b2dd0>>
# 0.05
# 0.85
# 19.361
# 0
# <bound method AHAP.add_haptic_transient_event of <__main__.AHAP object at 0x1590b2dd0>>
# 0.05
# 0.85
# 19.971
# 0
# <bound method AHAP.add_haptic_transient_event of <__main__.AHAP object at 0x1590b2dd0>>
# 0.05
# 0.85
# 21.011
# 1
# <bound method AHAP.add_haptic_transient_event of <__main__.AHAP object at 0x1590b2dd0>>
# 0.95
# 0.6
# 21.061
# 0
# <bound method AHAP.add_haptic_transient_event of <__main__.AHAP object at 0x1590b2dd0>>
# 0.05
# 0.85
# 22.022
# 1
# <bound method AHAP.add_haptic_transient_event of <__main__.AHAP object at 0x1590b2dd0>>
# 0.95
# 0.6
# 22.072
# 1
# <bound method AHAP.add_haptic_transient_event of <__main__.AHAP object at 0x1590b2dd0>>
# 0.95
# 0.6
# 22.501
# 0
# <bound method AHAP.add_haptic_transient_event of <__main__.AHAP object at 0x1590b2dd0>>
# 0.05
# 0.85
# 23.442
# 0
# <bound method AHAP.add_haptic_transient_event of <__main__.AHAP object at 0x1590b2dd0>>
# 0.05
# 0.85
# 24.412
# 1
# <bound method AHAP.add_haptic_transient_event of <__main__.AHAP object at 0x1590b2dd0>>
# 0.95
# 0.6
# 24.462
# 0
# <bound method AHAP.add_haptic_transient_event of <__main__.AHAP object at 0x1590b2dd0>>
# 0.05
# 0.85
# 25.582
# 0
# <bound method AHAP.add_haptic_transient_event of <__main__.AHAP object at 0x1590b2dd0>>
# 0.05
# 0.85
# 25.802
# 1
# <bound method AHAP.add_haptic_transient_event of <__main__.AHAP object at 0x1590b2dd0>>
# 0.95
# 0.6
# 26.872
# 0
# <bound method AHAP.add_haptic_transient_event of <__main__.AHAP object at 0x1590b2dd0>>
# 0.05
# 0.85
# 26.972
# 1
# <bound method AHAP.add_haptic_transient_event of <__main__.AHAP object at 0x1590b2dd0>>
# 0.95
# 0.6
# 27.032
# 0
# <bound method AHAP.add_haptic_transient_event of <__main__.AHAP object at 0x1590b2dd0>>
# 0.05
# 0.85
# 27.442
# 2
# <bound method AHAP.add_haptic_transient_event of <__main__.AHAP object at 0x1590b2dd0>>
# 0.1
# 0.6
# 29.492
# 0
# <bound method AHAP.add_haptic_transient_event of <__main__.AHAP object at 0x1590b2dd0>>
# 0.05
# 0.85
# 32.122
# 0
# <bound method AHAP.add_haptic_transient_event of <__main__.AHAP object at 0x1590b2dd0>>
# 0.05
# 0.85
# 32.592
# 0
# <bound method AHAP.add_haptic_transient_event of <__main__.AHAP object at 0x1590b2dd0>>
# 0.05
# 0.85
# 33.532
# 0
# <bound method AHAP.add_haptic_transient_event of <__main__.AHAP object at 0x1590b2dd0>>
# 0.05
# 0.85
# 34.042
# 0
# <bound method AHAP.add_haptic_transient_event of <__main__.AHAP object at 0x1590b2dd0>>
# 0.05
# 0.85
# 35.112
# 0
# <bound method AHAP.add_haptic_transient_event of <__main__.AHAP object at 0x1590b2dd0>>
# 0.05
# 0.85
# 35.542
# 0
# <bound method AHAP.add_haptic_transient_event of <__main__.AHAP object at 0x1590b2dd0>>
# 0.05
# 0.85
# 37.863
# 1
# <bound method AHAP.add_haptic_transient_event of <__main__.AHAP object at 0x1590b2dd0>>
# 0.95
# 0.6
# 38.013
# 0
# <bound method AHAP.add_haptic_transient_event of <__main__.AHAP object at 0x1590b2dd0>>
# 0.05
# 0.85
# 38.823
# 1
# <bound method AHAP.add_haptic_transient_event of <__main__.AHAP object at 0x1590b2dd0>>
# 0.95
# 0.6
#
# 2
# <bound method AHAP.add_haptic_transient_event of <__main__.AHAP object at 0x1590b2dd0>>
# 0.1
# 0.6
# 215.374
# 4
# <bound method AHAP.add_haptic_continuous_event of <__main__.AHAP object at 0x1590b2dd0>>
# 0.15
# 0.55
# 215.465
# 2
# <bound method AHAP.add_haptic_transient_event of <__main__.AHAP object at 0x1590b2dd0>>
# 0.1
# 0.6
# 217.094
# 4
# <bound method AHAP.add_haptic_continuous_event of <__main__.AHAP object at 0x1590b2dd0>>
# 0.15
# 0.55
# 217.244
# 4
# <bound method AHAP.add_haptic_continuous_event of <__main__.AHAP object at 0x1590b2dd0>>
# 0.15
# 0.55
# 219.745
# 1
# <bound method AHAP.add_haptic_transient_event of <__main__.AHAP object at 0x1590b2dd0>>
# 0.95
# 0.6
# 219.806
# 1
# <bound method AHAP.add_haptic_transient_event of <__main__.AHAP object at 0x1590b2dd0>>
# 0.95
# 0.6
# 221.025
# 1
# <bound method AHAP.add_haptic_transient_event of <__main__.AHAP object at 0x1590b2dd0>>
# 0.95
# 0.6
# 231.256
# 1
# <bound method AHAP.add_haptic_transient_event of <__main__.AHAP object at 0x1590b2dd0>>
# 0.95
# 0.6
# 231.735
# 1
# <bound method AHAP.add_haptic_transient_event of <__main__.AHAP object at 0x1590b2dd0>>
# 0.95
# 0.6
# 234.007
# 4
# <bound method AHAP.add_haptic_continuous_event of <__main__.AHAP object at 0x1590b2dd0>>
# 0.15
# 0.55
# 237.137
# 3
# <bound method AHAP.add_haptic_transient_event of <__main__.AHAP object at 0x1590b2dd0>>
# 0.8
# 0.5
# 237.857
# 1
# <bound method AHAP.add_haptic_transient_event of <__main__.AHAP object at 0x1590b2dd0>>
# 0.95
# 0.6
# 238.817
# 2
# <bound method AHAP.add_haptic_transient_event of <__main__.AHAP object at 0x1590b2dd0>>
# 0.1
# 0.6
# 238.856
# 1
# <bound method AHAP.add_haptic_transient_event of <__main__.AHAP object at 0x1590b2dd0>>
# 0.95
# 0.6
# 240.137
# 3
# <bound method AHAP.add_haptic_transient_event of <__main__.AHAP object at 0x1590b2dd0>>
# 0.8
# 0.5
# 240.246
# 1
# <bound method AHAP.add_haptic_transient_event of <__main__.AHAP object at 0x1590b2dd0>>
# 0.95
# 0.6
# 240.337
# 1
# <bound method AHAP.add_haptic_transient_event of <__main__.AHAP object at 0x1590b2dd0>>
# 0.95
# 0.6
# 241.537
# 1
# <bound method AHAP.add_haptic_transient_event of <__main__.AHAP object at 0x1590b2dd0>>
# 0.95
# 0.6
# 241.556
# 1
# <bound method AHAP.add_haptic_transient_event of <__main__.AHAP object at 0x1590b2dd0>>
# 0.95
# 0.6
# 242.616
# 1
# <bound method AHAP.add_haptic_transient_event of <__main__.AHAP object at 0x1590b2dd0>>
# 0.95
# 0.6
# 242.737
# 4
# <bound method AHAP.add_haptic_continuous_event of <__main__.AHAP object at 0x1590b2dd0>>
# 0.15
# 0.55
# 243.046
# 1
# <bound method AHAP.add_haptic_transient_event of <__main__.AHAP object at 0x1590b2dd0>>
# 0.95
# 0.6
# 247.698
# 1
# <bound method AHAP.add_haptic_transient_event of <__main__.AHAP object at 0x1590b2dd0>>
# 0.95
# 0.6
# 248.688
# 2
# <bound method AHAP.add_haptic_transient_event of <__main__.AHAP object at 0x1590b2dd0>>
# 0.1
# 0.6
# 250.367
# 1
# <bound method AHAP.add_haptic_transient_event of <__main__.AHAP object at 0x1590b2dd0>>
# 0.95
# 0.6
# 251.828
# 2
# <bound method AHAP.add_haptic_transient_event of <__main__.AHAP object at 0x1590b2dd0>>
# 0.1
# 0.6
# 251.927
# 1
# <bound method AHAP.add_haptic_transient_event of <__main__.AHAP object at 0x1590b2dd0>>
# 0.95
# 0.6
# 252.088
# 3
# <bound method AHAP.add_haptic_transient_event of <__main__.AHAP object at 0x1590b2dd0>>
# 0.8
# 0.5
# 252.497
# 1
# <bound method AHAP.add_haptic_transient_event of <__main__.AHAP object at 0x1590b2dd0>>
# 0.95
# 0.6
# 253.138
# 1
# <bound method AHAP.add_haptic_transient_event of <__main__.AHAP object at 0x1590b2dd0>>
# 0.95
# 0.6
# 254.797
# 1
# <bound method AHAP.add_haptic_transient_event of <__main__.AHAP object at 0x1590b2dd0>>
# 0.95
# 0.6
# 254.938
# 2
# <bound method AHAP.add_haptic_transient_event of <__main__.AHAP object at 0x1590b2dd0>>
# 0.1
# 0.6
# 255.977
# 1
# <bound method AHAP.add_haptic_transient_event of <__main__.AHAP object at 0x1590b2dd0>>
# 0.95
# 0.6
# 256.888
# 2
# <bound method AHAP.add_haptic_transient_event of <__main__.AHAP object at 0x1590b2dd0>>
# 0.1
# 0.6
# 257.578
# 2
# <bound method AHAP.add_haptic_transient_event of <__main__.AHAP object at 0x1590b2dd0>>
# 0.1
# 0.6
# 258.777
# 1
# <bound method AHAP.add_haptic_transient_event of <__main__.AHAP object at 0x1590b2dd0>>
# 0.95
# 0.6
# 259.078
# 1
# <bound method AHAP.add_haptic_transient_event of <__main__.AHAP object at 0x1590b2dd0>>
# 0.95
# 0.6
# 263.047
# 1
# <bound method AHAP.add_haptic_transient_event of <__main__.AHAP object at 0x1590b2dd0>>
# 0.95
# 0.6
# 265.809
# 3
# <bound method AHAP.add_haptic_transient_event of <__main__.AHAP object at 0x1590b2dd0>>
# 0.8
# 0.5

# %% [markdown]
# ## Simplified

# %%
data = pd.read_csv('cymbal_tracks/thillana_p2.csv', names=['time'])
data.head()
# Out:
#         time
# 0  12.076055
# 1  12.566078
# 2  13.106781
# 3  13.327529
# 4  13.594037

# %%
## adjust time
# data['time'] = data['time']+6
# data.head()
# Out:
#         time
# 0  23.263539
# 1  23.694673
# 2  25.553040
# 3  25.840274
# 4  26.161566

# %%
## write file - continuous
ahap = AHAP()

# ahap.add_haptic_transient_event(0, 0.99, 0.99)
# ahap.add_haptic_transient_event(1, 0.99, 0.99)
# ahap.add_haptic_transient_event(2, 0.99, 0.99)
# ahap.add_haptic_transient_event(3, 0.99, 0.99)
# ahap.add_haptic_transient_event(4, 0.99, 0.99)
# ahap.add_haptic_transient_event(5, 0.99, 0.99)
# ahap.add_haptic_transient_event(6, 0.99, 0.99)

for idx, event in data.iterrows():
    time = event['time']
    ahap.add_haptic_continuous_event(time, 0.99, 0.99, 0.02)

# %%
## write file - transient
ahap2 = AHAP()

ahap2.add_haptic_transient_event(0, 0.99, 0.99)
ahap2.add_haptic_transient_event(1, 0.99, 0.99)
ahap2.add_haptic_transient_event(2, 0.99, 0.99)
ahap2.add_haptic_transient_event(3, 0.99, 0.99)
ahap2.add_haptic_transient_event(4, 0.99, 0.99)
ahap2.add_haptic_transient_event(5, 0.99, 0.99)
ahap2.add_haptic_transient_event(6, 0.99, 0.99)

for idx, event in data.iterrows():
    time = event['time']
    ahap2.add_haptic_transient_event(time, 0.99, 0.99)

# %%
## print ahap
ahap.data
# Out:
# {'Version': 1.0,
#  'Metadata': {'Project': 'Basis',
#   'Created': '2023-11-15 09:16:23.452550',
#   'Description': 'AHAP file generated based on a audio file by Basis app.',
#   'Created By': 'Isabella Gomez'},
#  'Pattern': [{'Event': {'Time': 0,
#     'EventType': 'HapticTransient',
#     'EventParameters': [{'ParameterID': 'HapticIntensity',
#       'ParameterValue': 0.99},
#      {'ParameterID': 'HapticSharpness', 'ParameterValue': 0.99}]}},
#   {'Event': {'Time': 1,
#     'EventType': 'HapticTransient',
#     'EventParameters': [{'ParameterID': 'HapticIntensity',
#       'ParameterValue': 0.99},
#      {'ParameterID': 'HapticSharpness', 'ParameterValue': 0.99}]}},
#   {'Event': {'Time': 2,
#     'EventType': 'HapticTransient',
#     'EventParameters': [{'ParameterID': 'HapticIntensity',
#       'ParameterValue': 0.99},
#      {'ParameterID': 'HapticSharpness', 'ParameterValue': 0.99}]}},
#   {'Event': {'Time': 15.129048413366,
#     'EventType': 'HapticContinuous',
#     'EventParameters': [{'ParameterID': 'HapticIntensity',
#       'ParameterValue': 0.8},
#      {'ParameterID': 'HapticSharpness', 'ParameterValue': 0.8}],
#     'EventDuration': 0.05}},
#   {'Event': {'Time': 15.6174157922874,
#     'EventType': 'HapticContinuous',
#     'EventParameters': [{'ParameterID': 'HapticIntensity',
#       'ParameterValue': 0.8},
#      {'ParameterID': 'HapticSharpness', 'ParameterValue': 0.8}],
#     'EventDuration': 0.05}},
#   {'Event': {'Time': 16.1297514267468,
#     'EventType': 'HapticContinuous',
#     'EventParameters': [{'ParameterID': 'HapticIntensity',
#       'ParameterValue': 0.8},
#      {'ParameterID': 'HapticSharpness', 'ParameterValue': 0.8}],
#     'EventDuration': 0.05}},
#   {'Event': {'Time': 16.366622190558502,
#     'EventType': 'HapticContinuous',
#     'EventParameters': [{'ParameterID': 'HapticIntensity',
#       'ParameterValue': 0.8},
#      {'ParameterID': 'HapticSharpness', 'ParameterValue': 0.8}],
#     'EventDuration': 0.05}},
#   {'Event': {'Time': 16.6225405746652,
#     'EventType': 'HapticContinuous',
#     'EventParameters': [{'ParameterID': 'HapticIntensity',
#       'ParameterValue': 0.8},
#      {'ParameterID': 'HapticSharpness', 'ParameterValue': 0.8}],
#     'EventDuration': 0.05}},
#   {'Event': {'Time': 17.1212707660567,
#     'EventType': 'HapticContinuous',
#     'EventParameters': [{'ParameterID': 'HapticIntensity',
#       'ParameterValue': 0.8},
#      {'ParameterID': 'HapticSharpness', 'ParameterValue': 0.8}],
#     'EventDuration': 0.05}},
#   {'Event': {'Time': 17.673379645751098,
#     'EventType': 'HapticContinuous',
#     'EventParameters': [{'ParameterID': 'HapticIntensity',
#       'ParameterValue': 0.8},
#      {'ParameterID': 'HapticSharpness', 'ParameterValue': 0.8}],
#     'EventDuration': 0.05}},
#   {'Event': {'Time': 18.1629941902871,
#     'EventType': 'HapticContinuous',
#     'EventParameters': [{'ParameterID': 'HapticIntensity',
#       'ParameterValue': 0.8},
#      {'ParameterID': 'HapticSharpness', 'ParameterValue': 0.8}],
#     'EventDuration': 0.05}},
#   {'Event': {'Time': 18.656259528713,
#     'EventType': 'HapticContinuous',
#     'EventParameters': [{'ParameterID': 'HapticIntensity',
#       'ParameterValue': 0.8},
#      {'ParameterID': 'HapticSharpness', 'ParameterValue': 0.8}],
#     'EventDuration': 0.05}},
#   {'Event': {'Time': 19.1468944814791,
#     'EventType': 'HapticContinuous',
#     'EventParameters': [{'ParameterID': 'HapticIntensity',
#       'ParameterValue': 0.8},
#      {'ParameterID': 'HapticSharpness', 'ParameterValue': 0.8}],
#     'EventDuration': 0.05}},
#   {'Event': {'Time':

#     'EventType': 'HapticContinuous',
#     'EventParameters': [{'ParameterID': 'HapticIntensity',
#       'ParameterValue': 0.8},
#      {'ParameterID': 'HapticSharpness', 'ParameterValue': 0.8}],
#     'EventDuration': 0.05}},
#   {'Event': {'Time': 95.8833167404251,
#     'EventType': 'HapticContinuous',
#     'EventParameters': [{'ParameterID': 'HapticIntensity',
#       'ParameterValue': 0.8},
#      {'ParameterID': 'HapticSharpness', 'ParameterValue': 0.8}],
#     'EventDuration': 0.05}},
#   {'Event': {'Time': 96.1292804753539,
#     'EventType': 'HapticContinuous',
#     'EventParameters': [{'ParameterID': 'HapticIntensity',
#       'ParameterValue': 0.8},
#      {'ParameterID': 'HapticSharpness', 'ParameterValue': 0.8}],
#     'EventDuration': 0.05}},
#   {'Event': {'Time': 96.3865140522905,
#     'EventType': 'HapticContinuous',
#     'EventParameters': [{'ParameterID': 'HapticIntensity',
#       'ParameterValue': 0.8},
#      {'ParameterID': 'HapticSharpness', 'ParameterValue': 0.8}],
#     'EventDuration': 0.05}},
#   {'Event': {'Time': 96.6359244994631,
#     'EventType': 'HapticContinuous',
#     'EventParameters': [{'ParameterID': 'HapticIntensity',
#       'ParameterValue': 0.8},
#      {'ParameterID': 'HapticSharpness', 'ParameterValue': 0.8}],
#     'EventDuration': 0.05}},
#   {'Event': {'Time': 96.9015027481481,
#     'EventType': 'HapticContinuous',
#     'EventParameters': [{'ParameterID': 'HapticIntensity',
#       'ParameterValue': 0.8},
#      {'ParameterID': 'HapticSharpness', 'ParameterValue': 0.8}],
#     'EventDuration': 0.05}},
#   {'Event': {'Time': 97.3885095827628,
#     'EventType': 'HapticContinuous',
#     'EventParameters': [{'ParameterID': 'HapticIntensity',
#       'ParameterValue': 0.8},
#      {'ParameterID': 'HapticSharpness', 'ParameterValue': 0.8}],
#     'EventDuration': 0.05}},
#   {'Event': {'Time': 97.8731127891021,
#     'EventType': 'HapticContinuous',
#     'EventParameters': [{'ParameterID': 'HapticIntensity',
#       'ParameterValue': 0.8},
#      {'ParameterID': 'HapticSharpness', 'ParameterValue': 0.8}],
#     'EventDuration': 0.05}},
#   {'Event': {'Time': 98.1300742571774,
#     'EventType': 'HapticContinuous',
#     'EventParameters': [{'ParameterID': 'HapticIntensity',
#       'ParameterValue': 0.8},
#      {'ParameterID': 'HapticSharpness', 'ParameterValue': 0.8}],
#     'EventDuration': 0.05}},
#   {'Event': {'Time': 98.3804824368416,
#     'EventType': 'HapticContinuous',
#     'EventParameters': [{'ParameterID': 'HapticIntensity',
#       'ParameterValue': 0.8},
#      {'ParameterID': 'HapticSharpness', 'ParameterValue': 0.8}],
#     'EventDuration': 0.05}},
#   {'Event': {'Time': 98.6235663529877,
#     'EventType': 'HapticContinuous',
#     'EventParameters': [{'ParameterID': 'HapticIntensity',
#       'ParameterValue': 0.8},
#      {'ParameterID': 'HapticSharpness', 'ParameterValue': 0.8}],
#     'EventDuration': 0.05}},
#   {'Event': {'Time': 98.8607545771377,
#     'EventType': 'HapticContinuous',
#     'EventParameters': [{'ParameterID': 'HapticIntensity',
#       'ParameterValue': 0.8},
#      {'ParameterID': 'HapticSharpness', 'ParameterValue': 0.8}],
#     'EventDuration': 0.05}},
#   {'Event': {'Time': 99.1148815779072,
#     'EventType': 'HapticContinuous',
#     'EventParameters': [{'ParameterID': 'HapticIntensity',
#       'ParameterValue': 0.8},
#      {'ParameterID': 'HapticSharpness', 'ParameterValue': 0.8}],
#     'EventDuration': 0.05}},
#   {'Event': {'Time': 199.076225992749,
#     'EventType': 'HapticContinuous',
#     'EventParameters': [{'ParameterID': 'HapticIntensity',
#       'ParameterValue': 0.8},
#      {'ParameterID': 'HapticSharpness', 'ParameterValue': 0.8}],
#     'EventDuration': 0.05}},
#   {'Event': {'Time': 199.566951648469,
#     'EventType': 'HapticContinuous',
#     'EventParameters': [{'ParameterID': 'HapticIntensity',
#       'ParameterValue': 0.8},
#      {'ParameterID': 'HapticSharpness', 'ParameterValue': 0.8}],
#     'EventDuration': 0.05}},
#   {'Event': {'Time': 199.817019692056,
#     'EventType': 'HapticContinuous',
#     'EventParameters': [{'ParameterID': 'HapticIntensity',
#       'ParameterValue': 0.8},
#      {'ParameterID': 'HapticSharpness', 'ParameterValue': 0.8}],
#     'EventDuration': 0.05}},
#   {'Event': {'Time': 200.551418833122,
#     'EventType': 'HapticContinuous',
#     'EventParameters': [{'ParameterID': 'HapticIntensity',
#       'ParameterValue': 0.8},
#      {'ParameterID': 'HapticSharpness', 'ParameterValue': 0.8}],
#     'EventDuration': 0.05}},
#   {'Event': {'Time': 200.784071909583,
#     'EventType': 'HapticContinuous',
#     'EventParameters': [{'ParameterID': 'HapticIntensity',
#       'ParameterValue': 0.8},
#      {'ParameterID': 'HapticSharpness', 'ParameterValue': 0.8}],
#     'EventDuration': 0.05}},
#   {'Event': {'Time': 201.570217085783,
#     'EventType': 'HapticContinuous',
#     'EventParameters': [{'ParameterID': 'HapticIntensity',
#       'ParameterValue': 0.8},
#      {'ParameterID': 'HapticSharpness', 'ParameterValue': 0.8}],
#     'EventDuration': 0.05}},
#   {'Event': {'Time': 201.803618461613,
#     'EventType': 'HapticContinuous',
#     'EventParameters': [{'ParameterID': 'HapticIntensity',
#       'ParameterValue': 0.8},
#      {'ParameterID': 'HapticSharpness', 'ParameterValue': 0.8}],
#     'EventDuration': 0.05}},
#   {'Event': {'Time': 202.651736430987,
#     'EventType': 'HapticContinuous',
#     'EventParameters': [{'ParameterID': 'HapticIntensity',
#       'ParameterValue': 0.8},
#      {'ParameterID': 'HapticSharpness', 'ParameterValue': 0.8}],
#     'EventDuration': 0.05}},
#   {'Event': {'Time': 202.781849818193,
#     'EventType': 'HapticContinuous',
#     'EventParameters': [{'ParameterID': 'HapticIntensity',
#       'ParameterValue': 0.8},
#      {'ParameterID': 'HapticSharpness', 'ParameterValue': 0.8}],
#     'EventDuration': 0.05}},
# ...
#     'EventParameters': [{'ParameterID': 'HapticIntensity',
#       'ParameterValue': 0.8},
#      {'ParameterID': 'HapticSharpness', 'ParameterValue': 0.8}],
#     'EventDuration': 0.05}},
#   {'Event': {'Time': 295.555846823568,
#     'EventType': 'HapticContinuous',
#     'EventParameters': [{'ParameterID': 'HapticIntensity',
#       'ParameterValue': 0.8},
#      {'ParameterID': 'HapticSharpness', 'ParameterValue': 0.8}],
#     'EventDuration': 0.05}},
#   {'Event': {'Time': 295.789293550874,
#     'EventType': 'HapticContinuous',
#     'EventParameters': [{'ParameterID': 'HapticIntensity',
#       'ParameterValue': 0.8},
#      {'ParameterID': 'HapticSharpness', 'ParameterValue': 0.8}],
#     'EventDuration': 0.05}},
#   {'Event': {'Time': 296.037502183909,
#     'EventType': 'HapticContinuous',
#     'EventParameters': [{'ParameterID': 'HapticIntensity',
#       'ParameterValue': 0.8},
#      {'ParameterID': 'HapticSharpness', 'ParameterValue': 0.8}],
#     'EventDuration': 0.05}},
#   {'Event': {'Time': 296.294032812954,
#     'EventType': 'HapticContinuous',
#     'EventParameters': [{'ParameterID': 'HapticIntensity',
#       'ParameterValue': 0.8},
#      {'ParameterID': 'HapticSharpness', 'ParameterValue': 0.8}],
#     'EventDuration': 0.05}},
#   {'Event': {'Time': 296.54221877025,
#     'EventType': 'HapticContinuous',
#     'EventParameters': [{'ParameterID': 'HapticIntensity',
#       'ParameterValue': 0.8},
#      {'ParameterID': 'HapticSharpness', 'ParameterValue': 0.8}],
#     'EventDuration': 0.05}},
#   {'Event': {'Time': 296.777842368447,
#     'EventType': 'HapticContinuous',
#     'EventParameters': [{'ParameterID': 'HapticIntensity',
#       'ParameterValue': 0.8},
#      {'ParameterID': 'HapticSharpness', 'ParameterValue': 0.8}],
#     'EventDuration': 0.05}},
#   {'Event': {'Time': 297.029134901911,
#     'EventType': 'HapticContinuous',
#     'EventParameters': [{'ParameterID': 'HapticIntensity',
#       'ParameterValue': 0.8},
#      {'ParameterID': 'HapticSharpness', 'ParameterValue': 0.8}],
#     'EventDuration': 0.05}},
#   {'Event': {'Time': 297.275121312578,
#     'EventType': 'HapticContinuous',
#     'EventParameters': [{'ParameterID': 'HapticIntensity',
#       'ParameterValue': 0.8},
#      {'ParameterID': 'HapticSharpness', 'ParameterValue': 0.8}],
#     'EventDuration': 0.05}},
#   {'Event': {'Time': 297.527797066087,
#     'EventType': 'HapticContinuous',
#     'EventParameters': [{'ParameterID': 'HapticIntensity',
#       'ParameterValue': 0.8},
#      {'ParameterID': 'HapticSharpness', 'ParameterValue': 0.8}],
#     'EventDuration': 0.05}},
#   {'Event': {'Time': 297.780041980566,
#     'EventType': 'HapticContinuous',
#     'EventParameters': [{'ParameterID': 'HapticIntensity',
#       'ParameterValue': 0.8},
#      {'ParameterID': 'HapticSharpness', 'ParameterValue': 0.8}],
#     'EventDuration': 0.05}},
#   {'Event': {'Time': 298.052332247831,
#     'EventType': 'HapticContinuous',
#     'EventParameters': [{'ParameterID': 'HapticIntensity',
#       'ParameterValue': 0.8},
#      {'ParameterID': 'HapticSharpness', 'ParameterValue': 0.8}],
#     'EventDuration': 0.05}},
#   {'Event': {'Time': 298.295438839715,
#     'EventType': 'HapticContinuous',
#     'EventParameters': [{'ParameterID': 'HapticIntensity',
#       'ParameterValue': 0.8},
#      {'ParameterID': 'HapticSharpness', 'ParameterValue': 0.8}],
#     'EventDuration': 0.05}},
#   {'Event': {'Time': 298.561878766461,
#     'EventType': 'HapticContinuous',
#     'EventParameters': [{'ParameterID': 'HapticIntensity',
#       'ParameterValue': 0.8},
#      {'ParameterID': 'HapticSharpness', 'ParameterValue': 0.8}],
#     'EventDuration': 0.05}},
#   {'Event': {'Time': 298.792491026462,
#     'EventType': 'HapticContinuous',
#     'EventParameters': [{'ParameterID': 'HapticIntensity',
#       'ParameterValue': 0.8},
#      {'ParameterID': 'HapticSharpness', 'ParameterValue': 0.8}],
#     'EventDuration': 0.05}},
#   {'Event': {'Time': 299.047547732507,
#     'EventType': 'HapticContinuous',
#     'EventParameters': [{'ParameterID': 'HapticIntensity',
#       'ParameterValue': 0.8},
#      {'ParameterID': 'HapticSharpness', 'ParameterValue': 0.8}],
#     'EventDuration': 0.05}},
#   {'Event': {'Time': 299.285960446534,
#     'EventType': 'HapticContinuous',
#     'EventParameters': [{'ParameterID': 'HapticIntensity',
#       'ParameterValue': 0.8},
#      {'ParameterID': 'HapticSharpness', 'ParameterValue': 0.8}],
#     'EventDuration': 0.05}},
#   {'Event': {'Time': 299.547071574745,
#     'EventType': 'HapticContinuous',
#     'EventParameters': [{'ParameterID': 'HapticIntensity',
#       'ParameterValue': 0.8},
#      {'ParameterID': 'HapticSharpness', 'ParameterValue': 0.8}],
#     'EventDuration': 0.05}},
#   {'Event': {'Time': 299.794622611365,
#     'EventType': 'HapticContinuous',
#     'EventParameters': [{'ParameterID': 'HapticIntensity',
#       'ParameterValue': 0.8},
#      {'ParameterID': 'HapticSharpness', 'ParameterValue': 0.8}],
#     'EventDuration': 0.05}},
#   {'Event': {'Time': 300.053783626069,
#     'EventType': 'HapticContinuous',
#     'EventParameters': [{'ParameterID': 'HapticIntensity',
#       'ParameterValue': 0.8},
#      {'ParameterID': 'HapticSharpness', 'ParameterValue': 0.8}],
#     'EventDuration': 0.05}},
#   {'Event': {'Time': 300.303398154888,
#     'EventType': 'HapticContinuous',
#     'EventParameters': [{'ParameterID': 'HapticIntensity',
#       'ParameterValue': 0.8},
#      {'ParameterID': 'HapticSharpness', 'ParameterValue': 0.8}],
#     'EventDuration': 0.05}},
#   {'Event': {'Time': 300.555212230336,
#     'EventType': 'HapticContinuous',
#     'EventParameters': [{'ParameterID': 'HapticIntensity',
#       'ParameterValue': 0.8},
#      {'ParameterID': 'HapticSharpness', 'ParameterValue': 0.8}],
#     'EventDuration': 0.05}},
#   {'Event': {'Time': 300.795575057868,
#     'EventType': 'HapticContinuous',
#     'EventParameters': [{'ParameterID': 'HapticIntensity',
#       'ParameterValue': 0.8},
#      {'ParameterID': 'HapticSharpness', 'ParameterValue': 0.8}],
#     'EventDuration': 0.05}},
#   {'Event': {'Time': 301.048296162854,
#     'EventType': 'HapticContinuous',
#     'EventParameters': [{'ParameterID': 'HapticIntensity',
#       'ParameterValue': 0.8},
#      {'ParameterID': 'HapticSharpness', 'ParameterValue': 0.8}],
#     'EventDuration': 0.05}},
#   {'Event': {'Time': 301.289135180894,
#     'EventType': 'HapticContinuous',
#     'EventParameters': [{'ParameterID': 'HapticIntensity',
#       'ParameterValue': 0.8},
#      {'ParameterID': 'HapticSharpness', 'ParameterValue': 0.8}],
#     'EventDuration': 0.05}},
#   {'Event': {'Time': 301.538681682497,
#     'EventType': 'HapticContinuous',
#     'EventParameters': [{'ParameterID': 'HapticIntensity',
#       'ParameterValue': 0.8},
#      {'ParameterID': 'HapticSharpness', 'ParameterValue': 0.8}],
#     'EventDuration': 0.05}},
#   {'Event': {'Time': 301.77480414694,
#     'EventType': 'HapticContinuous',
#     'EventParameters': [{'ParameterID': 'HapticIntensity',
#       'ParameterValue': 0.8},
#      {'ParameterID': 'HapticSharpness', 'ParameterValue': 0.8}],
#     'EventDuration': 0.05}},
#   {'Event': {'Time': 302.044282622638,
#     'EventType': 'HapticContinuous',
#     'EventParameters': [{'ParameterID': 'HapticIntensity',
#       'ParameterValue': 0.8},
#      {'ParameterID': 'HapticSharpness', 'ParameterValue': 0.8}],
#     'EventDuration': 0.05}},
#   {'Event': {'Time': 302.276822320406,
#     'EventType': 'HapticContinuous',
#     'EventParameters': [{'ParameterID': 'HapticIntensity',
#       'ParameterValue': 0.8},
#      {'ParameterID': 'HapticSharpness', 'ParameterValue': 0.8}],
#     'EventDuration': 0.05}},
#   {'Event': {'Time': 302.650563841481,
#     'EventType': 'HapticContinuous',
#     'EventParameters': [{'ParameterID': 'HapticIntensity',
#       'ParameterValue': 0.8},
#      {'ParameterID': 'HapticSharpness', 'ParameterValue': 0.8}],
#     'EventDuration': 0.05}},
#   {'Event': {'Time': 302.783579723208,
#     'EventType': 'HapticContinuous',
#     'EventParameters': [{'ParameterID': 'HapticIntensity',
#       'ParameterValue': 0.8},
#      {'ParameterID': 'HapticSharpness', 'ParameterValue': 0.8}],
#     'EventDuration': 0.05}},
#   {'Event': {'Time': 303.039225998453,
#     'EventType': 'HapticContinuous',
#     'EventParameters': [{'ParameterID': 'HapticIntensity',
#       'ParameterValue': 0.8},
#      {'ParameterID': 'HapticSharpness', 'ParameterValue': 0.8}],
#     'EventDuration': 0.05}},
#   {'Event': {'Time': 303.286414223258,
#     'EventType': 'HapticContinuous',
#     'EventParameters': [{'ParameterID': 'HapticIntensity',
#       'ParameterValue': 0.8},
#      {'ParameterID': 'HapticSharpness', 'ParameterValue': 0.8}],
#     'EventDuration': 0.05}},
#   {'Event': {'Time': 303.544985668763,
#     'EventType': 'HapticContinuous',
#     'EventParameters': [{'ParameterID': 'HapticIntensity',
#       'ParameterValue': 0.8},
#      {'ParameterID': 'HapticSharpness', 'ParameterValue': 0.8}],
#     'EventDuration': 0.05}},
#   {'Event': {'Time': 303.784146682158,
#     'EventType': 'HapticContinuous',
#     'EventParameters': [{'ParameterID': 'HapticIntensity',
#       'ParameterValue': 0.8},
#      {'ParameterID': 'HapticSharpness', 'ParameterValue': 0.8}],
#     'EventDuration': 0.05}},
#   {'Event': {'Time': 304.046459624507,
#     'EventType': 'HapticContinuous',
#     'EventParameters': [{'ParameterID': 'HapticIntensity',
#       'ParameterValue': 0.8},
#      {'ParameterID': 'HapticSharpness', 'ParameterValue': 0.8}],
#     'EventDuration': 0.05}},
#   {'Event': {'Time': 304.29732131894,
#     'EventType': 'HapticContinuous',
#     'EventParameters': [{'ParameterID': 'HapticIntensity',
#       'ParameterValue': 0.8},
#      {'ParameterID': 'HapticSharpness', 'ParameterValue': 0.8}],
#     'EventDuration': 0.05}},
#   {'Event': {'Time': 304.549861018018,
#     'EventType': 'HapticContinuous',
#     'EventParameters': [{'ParameterID': 'HapticIntensity',
#       'ParameterValue': 0.8},
#      {'ParameterID': 'HapticSharpness', 'ParameterValue': 0.8}],
#     'EventDuration': 0.05}},
#   {'Event': {'Time': 304.791266929519,
#     'EventType': 'HapticContinuous',
#     'EventParameters': [{'ParameterID': 'HapticIntensity',
#       'ParameterValue': 0.8},
#      {'ParameterID': 'HapticSharpness', 'ParameterValue': 0.8}],
#     'EventDuration': 0.05}},
#   {'Event': {'Time': 305.036368986387,
#     'EventType': 'HapticContinuous',
#     'EventParameters': [{'ParameterID': 'HapticIntensity',
#       'ParameterValue': 0.8},
#      {'ParameterID': 'HapticSharpness', 'ParameterValue': 0.8}],
#     'EventDuration': 0.05}},
#   {'Event': {'Time': 305.292559479355,
#     'EventType': 'HapticContinuous',
#     'EventParameters': [{'ParameterID': 'HapticIntensity',
#       'ParameterValue': 0.8},
#      {'ParameterID': 'HapticSharpness', 'ParameterValue': 0.8}],
#     'EventDuration': 0.05}},
#   {'Event': {'Time': 305.547434779493,
#     'EventType': 'HapticContinuous',
#     'EventParameters': [{'ParameterID': 'HapticIntensity',
#       'ParameterValue': 0.8},
#      {'ParameterID': 'HapticSharpness', 'ParameterValue': 0.8}],
#     'EventDuration': 0.05}},
#   {'Event': {'Time': 305.785235248581,
#     'EventType': 'HapticContinuous',
#     'EventParameters': [{'ParameterID': 'HapticIntensity',
#       'ParameterValue': 0.8},
#      {'ParameterID': 'HapticSharpness', 'ParameterValue': 0.8}],
#     'EventDuration': 0.05}},
#   {'Event': {'Time': 306.041811229103,
#     'EventType': 'HapticContinuous',
#     'EventParameters': [{'ParameterID': 'HapticIntensity',
#       'ParameterValue': 0.8},
#      {'ParameterID': 'HapticSharpness', 'ParameterValue': 0.8}],
#     'EventDuration': 0.05}},
#   {'Event': {'Time': 306.26897677686,
#     'EventType': 'HapticContinuous',
#     'EventParameters': [{'ParameterID': 'HapticIntensity',
#       'ParameterValue': 0.8},
#      {'ParameterID': 'HapticSharpness', 'ParameterValue': 0.8}],
#     'EventDuration': 0.05}},
#   {'Event': {'Time': 306.648273853854,
#     'EventType': 'HapticContinuous',
#     'EventParameters': [{'ParameterID': 'HapticIntensity',
#       'ParameterValue': 0.8},
#      {'ParameterID': 'HapticSharpness', 'ParameterValue': 0.8}],
#     'EventDuration': 0.05}},
#   {'Event': {'Time': 306.77342125434,
#     'EventType': 'HapticContinuous',
#     'EventParameters': [{'ParameterID': 'HapticIntensity',
#       'ParameterValue': 0.8},
#      {'ParameterID': 'HapticSharpness', 'ParameterValue': 0.8}],
#     'EventDuration': 0.05}},
#   {'Event': {'Time': 307.036414468842,
#     'EventType': 'HapticContinuous',
#     'EventParameters': [{'ParameterID': 'HapticIntensity',
#       'ParameterValue': 0.8},
#      {'ParameterID': 'HapticSharpness', 'ParameterValue': 0.8}],
#     'EventDuration': 0.05}},
#   {'Event': {'Time': 308.052831768966,
#     'EventType': 'HapticContinuous',
#     'EventParameters': [{'ParameterID': 'HapticIntensity',
#       'ParameterValue': 0.8},
#      {'ParameterID': 'HapticSharpness', 'ParameterValue': 0.8}],
#     'EventDuration': 0.05}},
#   {'Event': {'Time': 308.282559675167,
#     'EventType': 'HapticContinuous',
#     'EventParameters': [{'ParameterID': 'HapticIntensity',
#       'ParameterValue': 0.8},
#      {'ParameterID': 'HapticSharpness', 'ParameterValue': 0.8}],
#     'EventDuration': 0.05}},
#   {'Event': {'Time': 308.634237702733,
#     'EventType': 'HapticContinuous',
#     'EventParameters': [{'ParameterID': 'HapticIntensity',
#       'ParameterValue': 0.8},
#      {'ParameterID': 'HapticSharpness', 'ParameterValue': 0.8}],
#     'EventDuration': 0.05}},
#   {'Event': {'Time': 308.779407780267,
#     'EventType': 'HapticContinuous',
#     'EventParameters': [{'ParameterID': 'HapticIntensity',
#       'ParameterValue': 0.8},
#      {'ParameterID': 'HapticSharpness', 'ParameterValue': 0.8}],
#     'EventDuration': 0.05}},
#   {'Event': {'Time': 309.020360176999,
#     'EventType': 'HapticContinuous',
#     'EventParameters': [{'ParameterID': 'HapticIntensity',
#       'ParameterValue': 0.8},
#      {'ParameterID': 'HapticSharpness', 'ParameterValue': 0.8}],
#     'EventDuration': 0.05}},
#   {'Event': {'Time': 309.146187849639,
#     'EventType': 'HapticContinuous',
#     'EventParameters': [{'ParameterID': 'HapticIntensity',
#       'ParameterValue': 0.8},
#      {'ParameterID': 'HapticSharpness', 'ParameterValue': 0.8}],
#     'EventDuration': 0.05}},
#   {'Event': {'Time': 309.387094894894,
#     'EventType': 'HapticContinuous',
#     'EventParameters': [{'ParameterID': 'HapticIntensity',
#       'ParameterValue': 0.8},
#      {'ParameterID': 'HapticSharpness', 'ParameterValue': 0.8}],
#     'EventDuration': 0.05}},
#   {'Event': {'Time': 309.510428236304,
#     'EventType': 'HapticContinuous',
#     'EventParameters': [{'ParameterID': 'HapticIntensity',
#       'ParameterValue': 0.8},
#      {'ParameterID': 'HapticSharpness', 'ParameterValue': 0.8}],
#     'EventDuration': 0.05}},
#   {'Event': {'Time': 309.762831880952,
#     'EventType': 'HapticContinuous',
#     'EventParameters': [{'ParameterID': 'HapticIntensity',
#       'ParameterValue': 0.8},
#      {'ParameterID': 'HapticSharpness', 'ParameterValue': 0.8}],
#     'EventDuration': 0.05}},
#   {'Event': {'Time': 310.010927135295,
#     'EventType': 'HapticContinuous',
#     'EventParameters': [{'ParameterID': 'HapticIntensity',
#       'ParameterValue': 0.8},
#      {'ParameterID': 'HapticSharpness', 'ParameterValue': 0.8}],
#     'EventDuration': 0.05}},
#   {'Event': {'Time': 310.267911279108,
#     'EventType': 'HapticContinuous',
#     'EventParameters': [{'ParameterID': 'HapticIntensity',
#       'ParameterValue': 0.8},
#      {'ParameterID': 'HapticSharpness', 'ParameterValue': 0.8}],
#     'EventDuration': 0.05}},
#   {'Event': {'Time': 310.610450984081,
#     'EventType': 'HapticContinuous',
#     'EventParameters': [{'ParameterID': 'HapticIntensity',
#       'ParameterValue': 0.8},
#      {'ParameterID': 'HapticSharpness', 'ParameterValue': 0.8}],
#     'EventDuration': 0.05}},
#   {'Event': {'Time': 310.738591582042,
#     'EventType': 'HapticContinuous',
#     'EventParameters': [{'ParameterID': 'HapticIntensity',
#       'ParameterValue': 0.8},
#      {'ParameterID': 'HapticSharpness', 'ParameterValue': 0.8}],
#     'EventDuration': 0.05}},
#   {'Event': {'Time': 311.015825160288,
#     'EventType': 'HapticContinuous',
#     'EventParameters': [{'ParameterID': 'HapticIntensity',
#       'ParameterValue': 0.8},
#      {'ParameterID': 'HapticSharpness', 'ParameterValue': 0.8}],
#     'EventDuration': 0.05}}]}

# %%
## export file

ahap.export(f'cymbal_tracks/thillana_p2.ahap','')
# ahap2.export(f'thillana/thillana2.ahap','')

# %% [markdown]
# ## Demos

# %%
d = [5.6851, 6.3747, 7.0192, 7.6613, 8.3413, 9.0361, 9.6793, 10.3422]
d2 = [round(x-d[0], 4) for x in d]
print(d2)
# Out:
# [0.0, 0.6896, 1.3341, 1.9762, 2.6562, 3.351, 3.9942, 4.6571]

# %%
d2 = [round(x + 3.486 + (3.486-3.0295), 4) for x in d2]
print(d2)
# Out:
# [3.9425, 4.1889, 4.4061, 4.6083, 4.8936, 5.1358, 5.344, 5.5774, 5.8297, 6.0772, 6.2903, 6.5098, 6.764, 7.0043, 7.2316, 7.458]

# %%
## write ahap
ahap_d = AHAP()

## demo 1: 0.0, 0.6016, 1.1734, 1.7899, 2.3947, 3.0079, 3.5927, 3.8596, 4.1451, 4.4286, 4.6953, 4.9924, 5.2896, 5.5598, 5.8525, 6.1363, 6.3902, 6.6766
# ahap_d.add_haptic_transient_event(0.0, 0.99, 0.99)
# ahap_d.add_haptic_transient_event(0.6016, 0.99, 0.99)
# ahap_d.add_haptic_transient_event(1.1734, 0.99, 0.99)
# ahap_d.add_haptic_transient_event(1.7899, 0.99, 0.99)
# ahap_d.add_haptic_transient_event(2.3947, 0.99, 0.99)
# ahap_d.add_haptic_transient_event(3.0079, 0.99, 0.99)
# ahap_d.add_haptic_transient_event(3.5927, 0.99, 0.99)
# ahap_d.add_haptic_transient_event(3.8596, 0.99, 0.99)
# ahap_d.add_haptic_transient_event(4.1451, 0.99, 0.99)
# ahap_d.add_haptic_transient_event(4.4286, 0.99, 0.99)
# ahap_d.add_haptic_transient_event(4.6953, 0.99, 0.99)
# ahap_d.add_haptic_transient_event(4.9924, 0.99, 0.99)
# ahap_d.add_haptic_transient_event(5.2896, 0.99, 0.99)
# ahap_d.add_haptic_transient_event(5.5598, 0.99, 0.99)
# ahap_d.add_haptic_transient_event(5.8525, 0.99, 0.99)
# ahap_d.add_haptic_transient_event(6.1363, 0.99, 0.99)
# ahap_d.add_haptic_transient_event(6.3902, 0.99, 0.99)
# ahap_d.add_haptic_transient_event(6.6766, 0.99, 0.99)


## demo 2: 0.0, 0.4727, 1.0213, 1.5063, 2.048, 2.5361, 3.0295, 3.486, 3.9425, 4.1889, 4.4061, 4.6083, 4.8936, 5.1358, 5.344, 5.5774, 5.8297, 6.0772, 6.2903, 6.5098, 6.764, 7.0043, 7.2316, 7.458
# ahap_d.add_haptic_transient_event(0.0, 0.99, 0.99)
# ahap_d.add_haptic_transient_event(0.4727, 0.99, 0.99)
# ahap_d.add_haptic_transient_event(1.0213, 0.99, 0.99)
# ahap_d.add_haptic_transient_event(1.5063, 0.99, 0.99)
# ahap_d.add_haptic_transient_event(2.048, 0.99, 0.99)
# ahap_d.add_haptic_transient_event(2.5361, 0.99, 0.99)
# ahap_d.add_haptic_transient_event(3.0295, 0.99, 0.99)
# ahap_d.add_haptic_transient_event(3.486, 0.99, 0.99)
# ahap_d.add_haptic_transient_event(3.9425, 0.99, 0.99)
# ahap_d.add_haptic_transient_event(4.1889, 0.99, 0.99)
# ahap_d.add_haptic_transient_event(4.4061, 0.99, 0.99)
# ahap_d.add_haptic_transient_event(4.6083, 0.99, 0.99)
# ahap_d.add_haptic_transient_event(4.8936, 0.99, 0.99)
# ahap_d.add_haptic_transient_event(5.1358, 0.99, 0.99)
# ahap_d.add_haptic_transient_event(5.344, 0.99, 0.99)
# ahap_d.add_haptic_transient_event(5.5774, 0.99, 0.99)
# ahap_d.add_haptic_transient_event(5.8297, 0.99, 0.99)
# ahap_d.add_haptic_transient_event(6.0772, 0.99, 0.99)
# ahap_d.add_haptic_transient_event(6.2903, 0.99, 0.99)
# ahap_d.add_haptic_transient_event(6.5098, 0.99, 0.99)
# ahap_d.add_haptic_transient_event(6.764, 0.99, 0.99)
# ahap_d.add_haptic_transient_event(7.0043, 0.99, 0.99)
# ahap_d.add_haptic_transient_event(7.2316, 0.99, 0.99)
# ahap_d.add_haptic_transient_event(7.458, 0.99, 0.99)


## demo 3: 0.0, 0.3359, 0.6372, 0.9474, 1.2521, 1.5656, 1.8706, 2.1728

## demo 5: 0.0, 0.6896, 1.3341, 1.9762, 2.6562, 3.351, 3.9942, 4.6571
ahap_d.add_haptic_continuous_event(0.0, 0.99, 0.99, 0.1)
ahap_d.add_haptic_transient_event(0.6896, 0.99, 0.99)
ahap_d.add_haptic_transient_event(1.3341, 0.99, 0.99)
ahap_d.add_haptic_transient_event(1.9762, 0.99, 0.99)
ahap_d.add_haptic_continuous_event(2.6562, 0.99, 0.99, 0.1)
ahap_d.add_haptic_transient_event(3.351, 0.99, 0.99)
ahap_d.add_haptic_transient_event(3.9942, 0.99, 0.99)
ahap_d.add_haptic_transient_event(4.6571, 0.99, 0.99)

## demo 6: 0.0, 0.2829, 1.1099, 1.8564, 3.3617, 4.0116, 4.3154, 4.6455, 4.9327, 5.2904, 5.9425, 6.5925, 7.2797, 8.1204, 8.6918, 9.2634, 9.5811, 9.8692
# ahap_d.add_haptic_continuous_event(0.0, 0.99, 0.6, 0.651)
# ahap_d.add_haptic_transient_event(0.6521, 0.99, 0.99)
# ahap_d.add_haptic_continuous_event(1.3021, 0.99, 0.6, 0.6861)
# ahap_d.add_haptic_transient_event(1.9893, 0.99, 0.99)
# ahap_d.add_haptic_transient_event(2.83, 0.99, 0.99)
# ahap_d.add_haptic_transient_event(3.4014, 0.99, 0.99)
# ahap_d.add_haptic_continuous_event(3.973, 0.99, 0.99, 0.02)
# ahap_d.add_haptic_continuous_event(4.2907, 0.99, 0.99, 0.02)
# ahap_d.add_haptic_continuous_event(4.5788, 0.99, 0.99, 0.02)

# ahap_d.add_haptic_continuous_event(5.2904, 0.99, 0.6, 0.651)
# ahap_d.add_haptic_transient_event(5.9425, 0.99, 0.99)
# ahap_d.add_haptic_continuous_event(6.5925, 0.99, 0.6, 0.6861)
# ahap_d.add_haptic_transient_event(7.2797, 0.99, 0.99)
# ahap_d.add_haptic_transient_event(8.1204, 0.99, 0.99)
# ahap_d.add_haptic_transient_event(8.6918, 0.99, 0.99)
# ahap_d.add_haptic_continuous_event(9.2634, 0.99, 0.99, 0.02)
# ahap_d.add_haptic_continuous_event(9.5811, 0.99, 0.99, 0.02)
# ahap_d.add_haptic_continuous_event(9.8692, 0.99, 0.99, 0.02)

# %%
## export
ahap_d.export(f'demos/demo5_mixed.ahap','')
